# %% [markdown]
# # You are given a text file named input.txt containing a list of words, one word per line. Your task is to create a Python program that reads the contents of input.txt, processes the words, and writes the result to an output file named output.txt. a. The program should perform the following operations: i. Read the words from input.txt. ii. For each word in the input file, calculate the length of the word and store it in a dictionary where the word is the key, and the length is the value. iii. Write the word-length dictionary to output.txt in the following format: Word1: Length1 Word2: Length2 iv. Close both input and output files properly. v. Write Python code to accomplish this task. Ensure proper error handling for file operations.

# %%
def read_words(file_path):
    try:
        with open(file_path, 'r') as file:
            words = file.read().split()
        return words
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
        return []
    except Exception as e:
        print(f"An error occurred: {e}")
        return []

file_path = 'one.txt'
words_list = read_words(file_path)

print("Words from 'one.txt':")
for word in words_list:
    print(word)
# Out:
# Words from 'one.txt':
# Python
# is
# a
# high-level,
# general-purpose
# programming
# language.
# Its
# design
# philosophy
# emphasizes
# code
# readability
# with
# the
# use
# of
# significant
# indentation.
# Python
# is
# dynamically
# typed
# and
# garbage-collected.
# It
# supports
# multiple
# programming
# paradigms,
# including
# structured
# (particularly
# procedural),
# object-oriented
# and
# functional
# programming.
# It
# is
# often
# described
# as
# a
# "batteries
# included"
# language
# due
# to
# its
# comprehensive
# standard
# library.
# Guido
# van
# Rossum
# began
# working
# on
# Python
# in
# the
# late
# 1980s
# as
# a
# successor
# to
# the
# ABC
# programming
# language
# and
# first
# released
# it
# in
# 1991
# as
# Python
# 0.9.0.Python
# 2.0
# was
# released
# in
# 2000.
# Python
# 3.0,
# released
# in
# 2008,
# was
# a
# major
# revision
# not
# completely
# backward-compatible
# with
# earlier
# versions.
# Python
# 2.7.18,
# released
# in
# ...

# %%
word_= {}
with open('one.txt', 'r') as file:
    content = file.read()
    words = content.split()
    
    for word in words:
        word = word.strip(".,!?()[]{}\"'")
        length = len(word)
        word_[word] = length

for word, length in word_.items():
    print(f'{word}: {length}')
# Out:
# Python: 6
# is: 2
# a: 1
# high-level: 10
# general-purpose: 15
# programming: 11
# language: 8
# Its: 3
# design: 6
# philosophy: 10
# emphasizes: 10
# code: 4
# readability: 11
# with: 4
# the: 3
# use: 3
# of: 2
# significant: 11
# indentation: 11
# dynamically: 11
# typed: 5
# and: 3
# garbage-collected: 17
# It: 2
# supports: 8
# multiple: 8
# paradigms: 9
# including: 9
# structured: 10
# particularly: 12
# procedural: 10
# object-oriented: 15
# functional: 10
# often: 5
# described: 9
# as: 2
# batteries: 9
# included: 8
# due: 3
# to: 2
# its: 3
# comprehensive: 13
# standard: 8
# library: 7
# Guido: 5
# van: 3
# Rossum: 6
# began: 5
# working: 7
# on: 2
# in: 2
# late: 4
# 1980s: 5
# successor: 9
# ABC: 3
# first: 5
# released: 8
# it: 2
# 1991: 4
# 0.9.0.Python: 12
# 2.0: 3
# was: 3
# 2000: 4
# 3.0: 3
# 2008: 4
# major: 5
# revision: 8
# not: 3
# completely: 10
# backward-compatible: 19
# earlier: 7
# versions: 8
# 2.7.18: 6
# 2020: 4
# last: 4
# release: 7
# 2: 1
# ...

# %%
word_len = {}
with open('one.txt', 'r') as file:
  
    content = file.read()
    words = content.split()
    for word in words:
        word = word.strip(".,!?()[]{}\"'")
        length = len(word)
        word_len[word] = length

with open('output.txt', 'w') as output_file:
    for word, length in word_len.items():
        output_file.write(f'{word}: {length}\n')

print("Word-length dictionary has been written to output.txt")
# Out:
# Word-length dictionary has been written to output.txt

# %%
try:
    with open('one.txt','r') as input_file:
    except FileNotFoundError:
        print("Input")
        except IOError as e:
            print(f"error: {e}")
            try:
                with open('output.txt','r') as output_file:
                    except IOError as e:
                        print(f"error: {e}")
# Out:
#   Cell In[12], line 3
#     except FileNotFoundError:
#     ^
# IndentationError: expected an indented block after 'with' statement on line 2

# %%
try:
    with open('one.txt', 'r') as input_file:
        input_data = input_file.read()

    with open('output.txt', 'w') as output_file:
        output_file.write(input_data)
    print("File operations completed successfully.")
except FileNotFoundError:
    print("Error: The input file was not found.")
except IOError as e:
    print(f"Error: An I/O error occurred - {e}")
except Exception as e:
    print(f"An unexpected error occurred - {e}")
# Out:
# File operations completed successfully.
